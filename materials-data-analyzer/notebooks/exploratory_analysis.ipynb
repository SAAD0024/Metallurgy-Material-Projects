# %% [markdown]
# # Exploratory Tensile-Test Analysis
#
# This notebook analyzes **synthetic example data**. The values are illustrative and must not be used for engineering design or material certification.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_DIR))
from analysis import descriptive_statistics, compare_materials, load_data
from plotting import create_all_plots

DATA_PATH = PROJECT_DIR / 'data' / 'raw' / 'tensile_test_results.csv'
data = load_data(DATA_PATH)
data.head()

# %%
statistics = descriptive_statistics(data)
statistics

# %%
comparison = compare_materials(data)
comparison

# %%
output_dir = PROJECT_DIR / 'data' / 'processed' / 'plots'
create_all_plots(data, output_dir)
print(f'Plots saved to {output_dir}')
